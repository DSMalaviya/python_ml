# %% [markdown]
# # matplotlib tutorial

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#ide ma alg window open karse jupyter notbook ma kai farak nai pade
import numpy as np
x=np.arange(1,10,.1)
y=2*x+5
plt.plot(x,y)
plt.show()
